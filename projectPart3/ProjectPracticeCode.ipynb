// %% [markdown]
// ## uint to char to uchar to uint?

// %%
#include <stdio.h>
 
int main(void) {
    
	unsigned int S = 0;
	unsigned int R = 1;
	char S_char = S + '0';
	char R_char = R + '0';
 
	unsigned int S_conv = (unsigned int)(unsigned char)(S_char - '0');
	unsigned int R_conv = (unsigned int)(unsigned char)(R_char - '0');
 
 
	printf("%u %u %u %u", S_conv, R_conv, S_char, R_char);
	return 0;
}
// Out:
// 0 1 48 49

// %% [markdown]
// ## for ACK, seqnum int -> char -> uchar (checksum) -> int

// %%
#include <stdio.h>
 
int main(void) {
	
	int S = 0;
	int R = 1;
    //put in char array
	char S_char = (char)S; 
	char R_char = (char)R;
    
    //take out for csum calc
	unsigned char S_uc = (unsigned char)S_char;
    unsigned char R_uc = (unsigned char)R_char;
    
    //compare with seqnum
    int S_int = (int)S_uc;
    int R_int = (int)R_uc;
 
 
	printf("%d %d", S_int, R_int );
	return 0;
}
// Out:
// 0 1

// %%
#include <stdio.h>

int main(void) {
	// your code goes here
	unsigned char csum = 0;
	int R = 1;
 
	if(csum==R)
		printf("True");
	else
		printf("False");
	return 0;
}
// Out:
// False

// %%
#include <stdio.h>

int main(void) {
	// your code goes here
	char nine = 9;
    int niner = (int)nine;
    //seqnums
    int R = 0;
    int S = 1;
    
    int resR = (int)(char)R;
    int resS = (int)(char)S;
    
    printf("%d, %d", resR, resS);
	return 0;
}
// Out:
// 0, 1

// %%
#include <stdio.h>

int main(void) {
	// your code goes here
	unsigned char csum = 240;
    
    unsigned char res = (unsigned char)(char)csum;
    
    printf("%u %u %u", csum, res, (unsigned int)res);
	return 0;
}
// Out:
// 240 240 240

// %%
#include <stdio.h>

int main(void) {
	int source_size = 2568;
    int num_segments = 2568/125;
    printf("num segments %d\n", num_segments);
    
    int remainder = 2568 % 125;
    printf("remainder %d\n", remainder);
	return 0;
}
// Out:
// num segments 20
// remainder 68

// %%
#include <stdio.h>

int main(void) {
	
	return 0;
}
